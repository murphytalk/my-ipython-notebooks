# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <div id="toc"></div>

# %% [markdown]
# # Fire up

# %%
import pandas as pd
import numpy as np

#%matplotlib --list
#%matplotlib inline
# %matplotlib nbagg
import matplotlib.pyplot as plt

# %% [markdown]
# # Load a tabular data set

# %%
sf = pd.read_csv('people-example.csv')

# %% [markdown]
# # SFrame basics

# %%
sf
# Out:
#   First Name Last Name        Country  age
# 0        Bob     Smith  United States   24
# 1      Alice  Williams         Canada   23
# 2    Malcolm      Jone        England   22
# 3      Felix     Brown            USA   23
# 4       Alex    Cooper         Poland   23
# 5        Tod  Campbell  United States   22
# 6      Derek      Ward    Switzerland   25

# %%
sf.tail()
# Out:
#   First Name Last Name        Country  age
# 2    Malcolm      Jone        England   22
# 3      Felix     Brown            USA   23
# 4       Alex    Cooper         Poland   23
# 5        Tod  Campbell  United States   22
# 6      Derek      Ward    Switzerland   25

# %% [markdown]
# Show data frame dimension:

# %%
sf.shape
# Out:
# (7, 4)

# %%
sf['Country']
# Out:
# 0    United States
# 1           Canada
# 2          England
# 3              USA
# 4           Poland
# 5    United States
# 6      Switzerland
# Name: Country, dtype: object

# %%
sf['age']
# Out:
# 0    24
# 1    23
# 2    22
# 3    23
# 4    23
# 5    22
# 6    25
# Name: age, dtype: int64

# %%
sf.describe()
# Out:
#              age
# count   7.000000
# mean   23.142857
# std     1.069045
# min    22.000000
# 25%    22.500000
# 50%    23.000000
# 75%    23.500000
# max    25.000000

# %%
# %matplotlib nbagg
sf.age.value_counts().plot(kind='bar')
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Inspect columns of dataset

# %%
sf['Country']
# Out:
# 0    United States
# 1           Canada
# 2          England
# 3              USA
# 4           Poland
# 5    United States
# 6      Switzerland
# Name: Country, dtype: object

# %%
sf['age']
# Out:
# 0    24
# 1    23
# 2    22
# 3    23
# 4    23
# 5    22
# 6    25
# Name: age, dtype: int64

# %%
sf.age
# Out:
# 0    24
# 1    23
# 2    22
# 3    23
# 4    23
# 5    22
# 6    25
# Name: age, dtype: int64

# %%
sf.age.mean()
# Out:
# 23.142857142857142

# %%
sf.age.max()
# Out:
# 25

# %% [markdown]
# # Create new columns in our SFrame

# %%
sf
# Out:
#   First Name Last Name        Country  age
# 0        Bob     Smith  United States   24
# 1      Alice  Williams         Canada   23
# 2    Malcolm      Jone        England   22
# 3      Felix     Brown            USA   23
# 4       Alex    Cooper         Poland   23
# 5        Tod  Campbell  United States   22
# 6      Derek      Ward    Switzerland   25

# %%
sf['Full Name'] = sf['First Name'] + ' ' + sf['Last Name']

# %%
sf
# Out:
#   First Name Last Name        Country  age       Full Name
# 0        Bob     Smith  United States   24       Bob Smith
# 1      Alice  Williams         Canada   23  Alice Williams
# 2    Malcolm      Jone        England   22    Malcolm Jone
# 3      Felix     Brown            USA   23     Felix Brown
# 4       Alex    Cooper         Poland   23     Alex Cooper
# 5        Tod  Campbell  United States   22    Tod Campbell
# 6      Derek      Ward    Switzerland   25      Derek Ward

# %%
sf['age'] * sf['age']
# Out:
# 0    576
# 1    529
# 2    484
# 3    529
# 4    529
# 5    484
# 6    625
# Name: age, dtype: int64

# %% [markdown]
# # Use the apply function to do a advance transformation of our data

# %%
sf.Country
# Out:
# 0    United States
# 1           Canada
# 2          England
# 3              USA
# 4           Poland
# 5    United States
# 6      Switzerland
# Name: Country, dtype: object

# %%
# %matplotlib nbagg
sf.Country.value_counts().plot(kind='bar')
# Out:
# <img src="data:image/png;base64,...">

# %%
sf.Country.describe()
# Out:
# count                 7
# unique                6
# top       United States
# freq                  2
# Name: Country, dtype: object

# %%
def transform_country(country):
    if country == 'USA':
        return 'United States'
    else:
        return country
sf['Country'].apply(transform_country)
# Out:
# 0    United States
# 1           Canada
# 2          England
# 3    United States
# 4           Poland
# 5    United States
# 6      Switzerland
# Name: Country, dtype: object

# %%
sf['Country'] = sf['Country'].apply(transform_country)
sf
# Out:
#   First Name Last Name        Country  age       Full Name
# 0        Bob     Smith  United States   24       Bob Smith
# 1      Alice  Williams         Canada   23  Alice Williams
# 2    Malcolm      Jone        England   22    Malcolm Jone
# 3      Felix     Brown  United States   23     Felix Brown
# 4       Alex    Cooper         Poland   23     Alex Cooper
# 5        Tod  Campbell  United States   22    Tod Campbell
# 6      Derek      Ward    Switzerland   25      Derek Ward

# %%
# %%javascript
# $.getScript('https://raw.githubusercontent.com/murphytalk/my-ipython-notebooks/master/ipython_notebook_goodies/ipython_notebook_toc.js')
